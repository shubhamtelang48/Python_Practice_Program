# %%
questions=[["Who developed the Python language?","Zim Den","Guido van Rossum","Niene Stom","Wick van Rossum","none",2],
           ["What is the maximum possible length of an identifier?",16,32,64,"none",4],
           ["In which language is Python written?","English","c","JavaScript","Php","none",4],
           ["What do we use to define a block of code in Python language?","Key","Brackets","Indentation","None of these","none",3],
           ["What is the method inside the class in python language?","Object","Function","Attribute","Argument","none",2],
           ["Which of the following declarations is incorrect?","_x = 2","__x = 3","__xyz__ = 5","None of these","none",4],
           ["Which of the following is not a keyword in Python language?","val","raise","try","with","none",1],
           ["Which of the following declarations is incorrect in python language?","xyzp = 5,000,000","x y z p = 5000 6000 7000 8000","x,y,z,p = 5000, 6000, 7000, 8000","x_y_z_p = 5,000,000","none",2],
           ["Which of the following is the most important language for Data Science?","Java","Ruby","R","None of the mentioned","none",3],
           ["Which of the following is not a step in data analysis?","Obtain the data","Clean the data","EDA","None of the mentioned","none",4],
           ["Which of the following technique comes under practical machine learning?","Bagging","Boosting","Forecasting","None of the mentioned","none",2],
           ["Which of the following technique is also referred to as Bagging?","Bootstrap aggregating","Bootstrap subsetting","Bootstrap predicting","All of the mentioned","none",1],
           ["Which of the following command allows you to change directory to one level above your parent directory?","cd","cd.","cd..","none of the mentioned","none",3],
           ["Which of the following is a revision control system?","Git","NumPy","Slidify","None of the mentioned","none",1],
          ["Point out the wrong statement.","min, max, idxmin, idxmax operations are supported on Series","You cannot pass a timedelta to get a particular value","Division by the numpy scalar is true division","None of the mentioned","none",3]]

levels=[1000,2000,3000,5000,10000,20000,40000,80000,160000,320000,640000,1250000,2500000,5000000,10000000]

money=0

for i in range(0, len(questions)):
    question=questions[i]

    print(f"\n\n Question for Rs.{levels[i]}")
    print(f"Q. {question[0]}")
    print(f"1.  {question[1]}")
    print(f"2.  {question[2]}")
    print(f"3.  {question[3]}")
    print(f"4.  {question[4]}")

    reply=int(input("Enter your Answer (1-4) or 0 to quit: \n"))

    if (reply==0):
        money=levels[i-1]
        break
    if (reply==question[-1]):
        print(f"Correct Answer, You have won Rs.{levels[i]}")
        if (i==4):
            money=10000
        elif (i==9):
            money=320000
        elif (i==14):
            money==10000000
    else:
        print("Wrong Answer!")
        break

print(f"You won total RS.{money}")
# Out:
#  Question for Rs.1000
# Q. Who developed the Python language?
# 1.  Zim Den
# 2.  Guido van Rossum
# 3.  Niene Stom
# 4.  Wick van Rossum
# Enter your Answer (1-4) or 0 to quit:
# 2
# Correct Answer, You have won Rs.1000
#
#
#  Question for Rs.2000
# Q. What is the maximum possible length of an identifier?
# 1.  16
# 2.  32
# 3.  64
# 4.  none
# Enter your Answer (1-4) or 0 to quit:
# 4
# Correct Answer, You have won Rs.2000
#
#
#  Question for Rs.3000
# Q. In which language is Python written?
# 1.  English
# 2.  c
# 3.  JavaScript
# 4.  Php
# Enter your Answer (1-4) or 0 to quit:
# 4
# Correct Answer, You have won Rs.3000
#
#
#  Question for Rs.5000
# Q. What do we use to define a block of code in Python language?
# 1.  Key
# 2.  Brackets
# 3.  Indentation
# 4.  None of these
# Enter your Answer (1-4) or 0 to quit:
# 3
# Correct Answer, You have won Rs.5000
#
#
#  Question for Rs.10000
# Q. What is the method inside the class in python language?
# 1.  Object
# 2.  Function
# ...
