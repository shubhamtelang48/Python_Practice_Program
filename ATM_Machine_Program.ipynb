# %% [markdown]
# # ATM Machine Python Program Using OOP

# %%
class Atm():

# constructor(special function)--not need to call
    def __init__(self):
        self.pin=''
        self.balance=0
        self.menu()

    def menu(self):
        user_input=input("""
        Hi how can I help you?
        1. Press 1 to create pin
        2. press 2 to change pin
        3. press 3 to check balance
        4. press 4 to withdraw
        5. press 5 to exit
        """)
        
        if user_input =='1':
        #create pin
          self.create_pin()
        elif user_input =='2':
        #change pin
          self.change_pin()
        elif user_input =='3':
        #check balance
          self.check_balance()
          
        elif user_input =='4':
        #withdraw
          self.withdraw()
        else:
             exit()
        
    def create_pin(self):
        user_pin=input('Enter your pin:')
        self.pin=user_pin
        
        user_balance=int(input('Enter your Balance Amount:'))
        self.balance=user_balance
        
        print('Pin created successfully')
        self.menu()
    
    def change_pin(self):
        old_pin=input('Enter old pin:')
        
        if old_pin==self.pin:
            new_pin=input('Enter new pin:')
            self.pin=new_pin
            print('pin change successful')
            self.menu()
        else:
            print('enter correct pin:')
            self.menu()
    
    def check_balance(self):
        user_pin=input('enter your pin:')
        
        if user_pin==self.pin:
            print('your current balance is: ',self.balance)
            self.menu()
        else:
            print('please enter currect pin:')
            self.menu()
            
    def withdraw(self):
        user_pin=input('enter your pin:')
        if user_pin==self.pin:
            amount=int(input('Enter the amount you want to withdraw from Atm'))
            if amount <= self.balance:
                self.balance = self.balance - amount
                print('Withdraw is successful and Your current balance is :',self.balance)
                self.menu()
            else:
                print('Insufficent balance')
                self.menu()
        else:
            print('please enter currect pin:')
            self.menu()

# %%
obj=Atm()
# Out:
#         Hi how can I help you?
#         1. Press 1 to create pin
#         2. press 2 to change pin
#         3. press 3 to check balance
#         4. press 4 to withdraw
#         5. press 5 to exit
#         3
# enter your pin:12345
# please enter currect pin:
#
#         Hi how can I help you?
#         1. Press 1 to create pin
#         2. press 2 to change pin
#         3. press 3 to check balance
#         4. press 4 to withdraw
#         5. press 5 to exit
#         1
# Enter your pin:1234
# Enter your Balance Amount:100000
# Pin created successfully
#
#         Hi how can I help you?
#         1. Press 1 to create pin
#         2. press 2 to change pin
#         3. press 3 to check balance
#         4. press 4 to withdraw
#         5. press 5 to exit
#         2
# Enter old pin:1234
# Enter new pin:12345
# pin change successful
#
#         Hi how can I help you?
#         1. Press 1 to create pin
#         2. press 2 to change pin
#         3. press 3 to check balance
# ...
